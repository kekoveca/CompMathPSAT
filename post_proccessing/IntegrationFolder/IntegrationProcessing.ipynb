# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import matplotlib.ticker as ticker

sns.set_theme(style= 'whitegrid', font_scale=1.5)

# %%
data = pd.read_csv('err.txt', header= None, dtype= np.float64)
h = [8., 4., 2., 1., 1./2., 1./4., 1./8., 1./16., 1./32., 1./64., 1./128., 1./256., 1./512., 1./1024.]
x_data = np.log(h)

# %%
y_data2 = np.log(data.iloc[0, :-1])
y_data3 = np.log(data.iloc[1, :-1])
y_data4 = np.log(data.iloc[2, :-1])
y_data5 = np.log(data.iloc[3, :-1])
y_data6 = np.log(data.iloc[4, :-1])
y_data15 = np.log(data.iloc[5, :-1])


p2 = np.polyfit(x_data[:-1], y_data2[:-1], 1)
y_2 = np.polyval(p2, x_data[:-1])
k2 = p2[0]

p3 = np.polyfit(x_data[:8], y_data3[:8], 1)
y_3 = np.polyval(p3, x_data[:8])
k3 = p3[0]

p4 = np.polyfit(x_data[:6], y_data4[:6], 1)
y_4 = np.polyval(p4, x_data[:6])
k4 = p4[0]

p5 = np.polyfit(x_data[:4], y_data5[:4], 1)
y_5 = np.polyval(p5, x_data[:4])
k5 = p5[0]

p6 = np.polyfit(x_data[:3], y_data6[:3], 1)
y_6 = np.polyval(p6, x_data[:3])
k6 = p6[0]

p15 = np.polyfit(x_data, y_data15, 1)
y_15 = np.polyval(p15, x_data)
k15 = p15[0]

fig = plt.figure(figsize= (16,10), dpi= 200)
ax = fig.add_subplot()
plt.xlim(-8, 3)

plt.scatter(x_data, y_data2, c = 'purple', label = f'N = 2: $\\tan \\alpha$ = {k2:.1f}')
plt.plot(x_data, y_data2, c = 'purple', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:-1], y_2, c = 'purple', linestyle = '--')

plt.scatter(x_data, y_data3, c = 'brown', label = f'N = 3: $\\tan \\alpha$ = {k3:.1f}')
plt.plot(x_data, y_data3, c = 'brown', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:8], y_3, c = 'brown', linestyle = '--')

plt.scatter(x_data, y_data4, c = 'red', label = f'N = 4: $\\tan \\alpha$ = {k4:.1f}')
plt.plot(x_data, y_data4, c = 'red', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:6], y_4, c = 'red', linestyle = '--')

plt.scatter(x_data, y_data5, c = 'blue', label = f'N = 5: $\\tan \\alpha$ = {k5:.1f}')
plt.plot(x_data, y_data5, c = 'blue', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:4], y_5, c = 'blue', linestyle = '--')

plt.scatter(x_data, y_data6, c = 'cyan', label = f'N = 6: $\\tan \\alpha$ = {k6:.1f}')
plt.plot(x_data, y_data6, c = 'cyan', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:3], y_6, c = 'cyan', linestyle = '--')


plt.scatter(x_data, y_data15, c = 'green', label = f'N = 15: ошибка порядка $10^{{-15}}$ при любом шаге')
plt.plot(x_data, y_data15, c = 'green', linestyle = ':', alpha = 0.3)

ax.yaxis.set_major_formatter(lambda x, pos: f'{np.exp(x):.1}')
ax.xaxis.set_major_formatter(lambda x, pos: f'{np.exp(x):.1}')

plt.title('График зависимости ошибки от шага в лог. масштабе для интегрирования $\sin x$ на отрезке $[0, 10]$\nИспользуются квадратуры Гаусса с N узлами')
plt.legend(loc = 'upper left')
plt.xlabel('$h$')
plt.ylabel('$err$')
plt.savefig(f'plot')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data = pd.read_csv('errRichardson.txt', header= None, dtype= np.float64)

# %%
y_data2 = np.log(data.iloc[0, :-1])
y_data22 = np.log(data.iloc[1, :-1])
y_data3 = np.log(data.iloc[2, :-1])
y_data33 = np.log(data.iloc[3, :-1])
y_data4 = np.log(data.iloc[4, :-1])
y_data44 = np.log(data.iloc[5, :-1])
y_data5 = np.log(data.iloc[6, :-1])
y_data55 = np.log(data.iloc[7, :-1])
y_data6 = np.log(data.iloc[8, :-1])
y_data66 = np.log(data.iloc[9, :-1])


p2 = np.polyfit(x_data[:-1], y_data2[:-1], 1)
y_2 = np.polyval(p2, x_data[:-1])
k2 = p2[0]
p22 = np.polyfit(x_data[:8], y_data22[:8], 1)
y_22 = np.polyval(p22, x_data[:8])
k22 = p22[0]

p3 = np.polyfit(x_data[:8], y_data3[:8], 1)
y_3 = np.polyval(p3, x_data[:8])
k3 = p3[0]
p33 = np.polyfit(x_data[:6], y_data33[:6], 1)
y_33 = np.polyval(p33, x_data[:6])
k33 = p33[0]

p4 = np.polyfit(x_data[:6], y_data4[:6], 1)
y_4 = np.polyval(p4, x_data[:6])
k4 = p4[0]
p44 = np.polyfit(x_data[:4], y_data44[:4], 1)
y_44 = np.polyval(p44, x_data[:4])
k44 = p44[0]

p5 = np.polyfit(x_data[:4], y_data5[:4], 1)
y_5 = np.polyval(p5, x_data[:4])
k5 = p5[0]
p55 = np.polyfit(x_data[:3], y_data55[:3], 1)
y_55 = np.polyval(p55, x_data[:3])
k55 = p55[0]

p6 = np.polyfit(x_data[:3], y_data6[:3], 1)
y_6 = np.polyval(p6, x_data[:3])
k6 = p6[0]
p66 = np.polyfit(x_data[:2], y_data66[:2], 1)
y_66 = np.polyval(p66, x_data[:2])
k66 = p66[0]


fig = plt.figure(figsize= (16,10), dpi= 200)
ax = fig.add_subplot()
plt.xlim(-8, 3)

plt.scatter(x_data, y_data2, c = 'purple', label = f'N = 2:\t\t$\\tan \\alpha$ = {k2:.1f}\nэкстр. Рич. $\\tan \\alpha$ = {k22:.1f}')
plt.plot(x_data, y_data2, c = 'purple', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:-1], y_2, c = 'purple', linestyle = '--')
plt.scatter(x_data, y_data22, c = 'purple')
plt.plot(x_data, y_data22, c = 'purple', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:8], y_22, c = 'purple', linestyle = '--')

plt.scatter(x_data, y_data3, c = 'brown', label = f'N = 3:\t\t$\\tan \\alpha$ = {k3:.1f}\nэкстр. Рич. $\\tan \\alpha$ = {k33:.1f}')
plt.plot(x_data, y_data3, c = 'brown', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:8], y_3, c = 'brown', linestyle = '--')
plt.scatter(x_data, y_data33, c = 'brown')
plt.plot(x_data, y_data33, c = 'brown', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:6], y_33, c = 'brown', linestyle = '--')

plt.scatter(x_data, y_data4, c = 'red', label = f'N = 4:\t\t$\\tan \\alpha$ = {k4:.1f}\nэкстр. Рич. $\\tan \\alpha$ = {k44:.1f}')
plt.plot(x_data, y_data4, c = 'red', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:6], y_4, c = 'red', linestyle = '--')
plt.scatter(x_data, y_data44, c = 'red')
plt.plot(x_data, y_data44, c = 'red', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:4], y_44, c = 'red', linestyle = '--')

plt.scatter(x_data, y_data5, c = 'blue', label = f'N = 5:\t\t$\\tan \\alpha$ = {k5:.1f}\nэкстр. Рич. $\\tan \\alpha$ = {k55:.1f}')
plt.plot(x_data, y_data5, c = 'blue', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:4], y_5, c = 'blue', linestyle = '--')
plt.scatter(x_data, y_data55, c = 'blue')
plt.plot(x_data, y_data55, c = 'blue', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:3], y_55, c = 'blue', linestyle = '--')

plt.scatter(x_data, y_data6, c = 'cyan', label = f'N = 6:\t\t$\\tan \\alpha$ = {k6:.1f}\nэкстр. Рич. $\\tan \\alpha$ = {k66:.1f}')
plt.plot(x_data, y_data6, c = 'cyan', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:3], y_6, c = 'cyan', linestyle = '--')
plt.scatter(x_data, y_data66, c = 'cyan')
plt.plot(x_data, y_data66, c = 'cyan', linestyle = ':', alpha = 0.3)
plt.plot(x_data[:2], y_66, c = 'cyan', linestyle = '--')

ax.yaxis.set_major_formatter(lambda x, pos: f'{np.exp(x):.1}')
ax.xaxis.set_major_formatter(lambda x, pos: f'{np.exp(x):.1}')

plt.title('График зависимости ошибки от шага в лог. масштабе для интегрирования $\sin x$ на отрезке $[0, 10]$\nИспользуются квадратуры Гаусса с N узлами')
plt.legend(loc = 'upper left')
plt.xlabel('$h$')
plt.ylabel('$err$')
plt.savefig(f'plotRichardson')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
